# %%
from urllib.parse import urljoin
import requests
import time
import pandas as pd

# base URL for GET request to obtain trade data
BASEURL = 'https://api.bitfinex.com/v2/trades/'
# coin pair to obtain trades for
SYMBOL = 'tIOTUSD'
# number of trades to obtain per query
LIMIT = 1000
# number of total requests to send
REQUESTS = 3000
# time between requests in seconds
WAIT = 1

# default value -> get the latest trades
last_timestamp = 0
successful_requests = 0
trades = []
for _ in range(REQUESTS):
    url = urljoin(BASEURL, f'{SYMBOL}/hist')
    query_time = time.time()
    # get <LIMIT> trades since last timestamp
    print(url)
    response = requests.get(url,
                            params={'limit': LIMIT,
                                    'start': last_timestamp})
    # if the request was successful, update data
    if response.status_code == 200:
        print('Request successful')
        successful_requests += 1
        trade_data = pd.DataFrame(response.json(),
                                  columns=['ID', 'MTS', 'AMOUNT', 'PRICE'])
        print(f'{len(trade_data)} trades since last timestamp')
        last_timestamp = max(trade_data['MTS'])
        trades.append(trade_data)
        # make sure we adhere to <WAIT> period
        timedelta = time.time() - query_time
        if timedelta < WAIT:
            time.sleep(WAIT - timedelta)

print(f'Completed {successful_requests} requests successfully')

all_trades = pd.concat(trades)
all_trades.to_parquet(f'{SYMBOL}_trades.parquet')
# Out:
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1000 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 5 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Request successful
# 1 trades since last timestamp
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# ...
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# https://api.bitfinex.com/v2/trades/tIOTUSD/hist
# Completed 38 requests successfully

# %%
from pyspark.sql import SparkSession as spark

# %%
df=spark.read.parquet("swift2d://tIOTUSD_trades.parquet")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-245026117f04> in <module>()
# ----> 1 df=spark.read.parquet("swift2d://tIOTUSD_trades.parquet")
#
# AttributeError: 'property' object has no attribute 'parquet'

# %%
import pandas as pd
df_new = pd.read_parquet('tIOTUSD_trades.parquet')
print(df_new.head())
# Out:
#               ID            MTS       AMOUNT   PRICE
# index
# 0      264763298  1530623041322  -212.190000  1.1835
# 1      264763297  1530623041240   -10.000000  1.1835
# 2      264763052  1530622998133  1366.805846  1.1848
# 3      264763051  1530622998131  1546.541305  1.1848
# 4      264763027  1530622989857  2241.098795  1.1848

# %%
import datetime
df_new['MTS'] = df_new['MTS']/1000
df_new['new date'] = df_new['MTS'].map(lambda val: datetime.datetime.fromtimestamp(val).
                                   strftime('%a, %m-%d-%Y %H:%M:%S'))
del df_new['MTS']

df1 = df_new.set_index("ID", drop = True)
df1.iloc[:,-1]
df_new.head()
# Out:
#               ID       AMOUNT   PRICE                  new date
# index
# 0      264763298  -212.190000  1.1835  Tue, 07-03-2018 15:04:01
# 1      264763297   -10.000000  1.1835  Tue, 07-03-2018 15:04:01
# 2      264763052  1366.805846  1.1848  Tue, 07-03-2018 15:03:18
# 3      264763051  1546.541305  1.1848  Tue, 07-03-2018 15:03:18
# 4      264763027  2241.098795  1.1848  Tue, 07-03-2018 15:03:09

# %%
df_new = df_new.set_index('new date')
print (df_new.head())
# Out:
#                                  ID       AMOUNT   PRICE
# new date
# Tue, 07-03-2018 15:04:01  264763298  -212.190000  1.1835
# Tue, 07-03-2018 15:04:01  264763297   -10.000000  1.1835
# Tue, 07-03-2018 15:03:18  264763052  1366.805846  1.1848
# Tue, 07-03-2018 15:03:18  264763051  1546.541305  1.1848
# Tue, 07-03-2018 15:03:09  264763027  2241.098795  1.1848

# %%
import matplotlib.pyplot as plt

x = df_new['PRICE']
y = df_new['AMOUNT']

plt.xlabel('Price')
plt.ylabel('Amount')


plt.scatter(x, y, s=300, linewidth=1)
plt.show()
